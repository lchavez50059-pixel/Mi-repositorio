# %% [markdown]
# # Título principal
# ## Subtítulo
#
# **Texto en negritas**
# *Texto en cursiva*
#
# - Lista
# - De
# - Elementos
#
# 1. Lista
# 2. Numerada
#
# [Enlace](https://jupyter.org)
#
# `código en línea`
#
# ```python
# print("Hola mundo")
